# %%
from flask import Flask,render_template,request,jsonify

# %%
from bs4 import BeautifulSoup as bs

# %%
from urllib.request import urlopen as urReq

# %%
flipkart_url='https://www.flipkart.com/search?q=iphone+12'

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone+12'

# %%
responce_website=urReq(flipkart_url)

# %%
data_flipkart=responce_website.read()

# %%
bs(data_flipkart,'html.parser')
# Out:
# <!DOCTYPE html>
# ...

# %%
beautified_html=bs(data_flipkart,'html.parser')

# %%
bigbox=beautified_html.find_all("div",{"class":"_1AtVbE col-12-12"})

# %%
bigbox[6].a['href']
# Out:
# '/apple-iphone-12-white-256-gb/p/itmcfbcb621e6326?pid=MOBFWBYZMNGZVMJE&lid=LSTMOBFWBYZMNGZVMJEAEBPN8&marketplace=FLIPKART&q=iphone+12&store=tyy%2F4io&srno=s_1_5&otracker=search&fm=organic&iid=fa126501-8ef6-4fdc-bfe3-0bcbef5f814d.MOBFWBYZMNGZVMJE.SEARCH&ppt=None&ppn=None&ssid=011p1gp5sw0000001661853002217&qH=7b7504afcaf2e1ea'

# %%
product6='https://www.flipkart.com'+bigbox[6].a['href']

# %%
product6
# Out:
# 'https://www.flipkart.com/apple-iphone-12-white-256-gb/p/itmcfbcb621e6326?pid=MOBFWBYZMNGZVMJE&lid=LSTMOBFWBYZMNGZVMJEAEBPN8&marketplace=FLIPKART&q=iphone+12&store=tyy%2F4io&srno=s_1_5&otracker=search&fm=organic&iid=fa126501-8ef6-4fdc-bfe3-0bcbef5f814d.MOBFWBYZMNGZVMJE.SEARCH&ppt=None&ppn=None&ssid=011p1gp5sw0000001661853002217&qH=7b7504afcaf2e1ea'

# %%
import requests

# %%
product66=requests.get(product6)

# %%
product66.encoding='utf-8'

# %%
product6_page=bs(product66.text,'html.parser')

# %%
all_review=product6_page.find_all('div',{"class":"_16PBlm"})

# %%
len(all_review)
# Out:
# 11

# %%
all_review[5].div.div.div.div.text
# Out:
# '5'

# %%
name=all_review[5].div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH"})[0].text
